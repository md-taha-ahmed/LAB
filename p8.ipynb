# %% [markdown]
# #### 8- Write a program to implement ***k-Nearest Neighbor*** algorithm to classify the iris data set.Print both correct and wrong predictions. Java/Python ML library classes can be used for this problem.

# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
def KNN(datax):
    print("Enter ur weight, height& chest size to buy right size ")
    a,b,c =input().split()
    a = int(a)
    b = int(b)
    c = int(c)
    for line in datax:
        x = int(line[0])
        y = int(line[1])
        z = int(line[2])
        
        dist = np.sqrt((x-a)**2+(y-b)**2+(z-c)**2)
        line.append(dist)
        
        
    print("How many nearest survey k= ")
    k = int(input())
    datax.sort(key = lambda i:i[4]) #order depend on the destines which it position in 4th place in datax
    print("k shortest distance")
    scount = 0
    lcount = 0
    mcount = 0
    xlcount = 0
    for j in range(k):
        print(datax[j])
        if datax[j][3]=='S':
            scount += 1
        if datax[j][3]=='M':
            mcount+=1
        if datax[j][3]=='L':
            lcount+=1
        if datax[j][3]=='XL':
            xlcount+=1
    x1=["S","M","L","XL"]
    y1=[scount,mcount,lcount,xlcount]
    plt.bar(x1,y1)
    plt.show()
    if(scount>mcount and scount>lcount and scount>xlcount):
        print("..........GO FOR SMALL SIZE........")
    elif(mcount>scount and mcount>lcount and mcount>xlcount):
        print("..........GO FOR MEDIUM SIZE......")
    elif(lcount>scount and lcount>mcount and lcount>xlcount):
        print("..........GO FOR LARGE SIZE.......")
    else:
        print("..........GO FOR XL SIZE...........")
    
    
    
def main():
    file = r"data/T-shirt1.csv"
    data=pd.read_csv(file)
    display(data)
    fd = csv.reader(open(file))
    datax=[]
    for line in fd:
        datax.append(line)
    KNN(datax[1:])
    

main()
# Out:
#     Weight  height  chestsize T-shirt size
# 0       55     170         45            S
# 1       67     172         49            M
# 2       70     169         47            M
# 3       80     174         49            L
# 4       88     175         50           XL
# 5       67     171         44            M
# 6       50     166         40            S
# 7       90     178         52           XL
# 8       98     175         50           XL
# 9       60     160         42            S
# 10      75     175         48            L
# 11      78     174         50            L
# 12      66     168         46            M
# 13      79     171         49            L
# 14      44     160         44            S
# 15      99     179         56           XL
# Enter ur weight & chest size to buy right size
# How many nearest survey k=
# k shortest distance
# ['55', '170', '45', 'S', 10.488088481701515]
# ['67', '171', '44', 'M', 10.488088481701515]
# ...

# %% [markdown]
# ### KNN on IRIS

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
def KNN(datax):
    print("ENTER IRIS speal length , speal width ,petal lenght and petal width")
    a,b,c,d=input().split()
    a=float(a)
    b=float(b)
    c=float(c)
    d=float(d)
    
    for line in datax:
        x=float(line[0])
        y=float(line[1])
        z=float(line[2])
        w=float(line[3])
        
        dist=np.sqrt((x-a)**2+(y-b)**2+(z-c)**2+(w-d)**2)        
        line.append(dist)
        
    #display(datax)
    print("HOW MANY NEARST SURVEY K=")
    k=int(input())
    datax.sort(key = lambda i: i[4])
    print("K sortest distance")
    #display(datax)
    vircount=0
    vercount=0
    setcount=0
    
    for j in range(k):
        print(datax[j])
        if datax[j][4]=='Iris-virginica':
            vircount+=1
        if datax[j][4]=='Iris-versicolor':
            vercount+=1
        if datax[j][4]=='Iris-setosa':
            setcount+=1
        
    if(vircount>vercount and vircount>setcount):
            print("..........IRIS FLOWER BELONG VIRGINICA CATOGARY.............")
    elif(vercount>vircount and vercount>setcount):
            print("..........IRIS FLOWER BELONG VERSICOLOR CATOGARY.............")
    else:    
            print("..........IRIS FLOWER BELONG SETOSA CATOGARY.............")      
   



def main():
    file="iris.csv"
    data=pd.read_csv(file)
    display(data)
    fd=csv.reader(open(file))
    datax=[]
    for line in fd:
        datax.append(line)
    KNN(datax[1:])      
        
main()
# Out:
#      slength  swidth  plength  pwidth        catogary
# 0        5.1     3.5      1.4     0.2     Iris-setosa
# 1        4.9     3.0      1.4     0.2     Iris-setosa
# 2        4.7     3.2      1.3     0.2     Iris-setosa
# 3        4.6     3.1      1.5     0.2     Iris-setosa
# 4        5.0     3.6      1.4     0.2     Iris-setosa
# ..       ...     ...      ...     ...             ...
# 145      6.7     3.0      5.2     2.3  Iris-virginica
# 146      6.3     2.5      5.0     1.9  Iris-virginica
# 147      6.5     3.0      5.2     2.0  Iris-virginica
# 148      6.2     3.4      5.4     2.3  Iris-virginica
# 149      5.9     3.0      5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ENTER IRIS speal length , speal width ,petal lenght and petal width
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 61
#      58         datax.append(line)
# ...
